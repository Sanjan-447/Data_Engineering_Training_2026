# %%
# !pip install ipywidgets

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
name_widget=widgets.Text(
    value="Rahul",
    description="Name"
)

display(name_widget)
# Out:
# Text(value='Rahul', description='Name')

# %%
dept_widget=widgets.Dropdown(
    options=["HR", "IT", "Finanace"],
    value="IT",
    description="Dept"
)
display(dept_widget)
# Out:
# Dropdown(description='Dept', index=1, options=('HR', 'IT', 'Finanace'), value='IT')

# %%
salary_slider=widgets.IntSlider(
    value=60000,
    min=10000,
    max=100000,
    step=5000,
    description="Salary"
)
display(salary_slider)
# Out:
# IntSlider(value=60000, description='Salary', max=100000, min=10000, step=5000)

# %%
button=widgets.Button(description="Show Values")

def on_button_click(b):
  print("Name : ",name_widget.value)
  print("Department : ", dept_widget.value)
  print("Salary : ", salary_slider.value)

button.on_click(on_button_click)
display(button)
